# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
import simuCRNs

# %% [markdown]
# # Interactive CRN Simulation Demo
# ## Loading Mass Action CRN from json spec

# %%
crn = simuCRNs.fromJSON("CRNs/cyclic_crn.json")
print( crn )
# Out:
# Test CRN
# initial relative concentrations:
# X:0.5 Y:0.25 Z:0.25
#
# reactions:
# 1. 2X + 3Y <-> Z [0.0001, 8e-06]
# 2. 2X -> Y + Z [0.003]
# 3. X ->  [0.229]
# 4. Z  + 5X <-> Y [0.4, 0.001]

# %% [markdown]
# ## Non interactive plotting

# %%
crn.plot_dynamics( figsize = (20, 10) )

# %% [markdown]
# ## Interactive plotting

# %%
display( crn.build_UI() )
# Out:
# OrderedDict([('k1', 0.0001), ('k-1', 8e-06), ('k2', 0.003), ('k3', 0.229), ('k4', 0.4), ('k-4', 0.001)])
# VBox(children=(Output(layout=Layout(height='740px')), FloatSlider(value=0.0001, description='rate k1', max=0.0…
